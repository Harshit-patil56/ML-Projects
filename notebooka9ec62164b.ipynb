# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('display.max_columns',200)

# %%
df = pd.read_csv('/kaggle/input/cost-of-international-education/International_Education_Costs.csv')

# %%
df.shape

# %%
df.head(5)

# %%
df.columns

# %%
df.dtypes

# %%
df.describe()

# %%
df.columns

# %%
#Example of droping columns
#df.drop(['Insurance_USD', 'Exchange_Rate'], axis=1)

df = df [['Country', 'City','Program', 'Visa_Fee_USD','Rent_USD']].copy()

# %%
df.head()

# %%
df.shape

# %%
df.dtypes

# %%
#Rename our columns
df = df.rename(columns={'Visa_Fee_USD':'Visa Fee USD','Rent_USD':'Rent USD'})

# %%
df.head

# %%
df.isna().sum()

# %%
df.duplicated()

# %%
ax = df['Visa Fee USD'].value_counts() \
    .head(10) \
    .plot(kind='bar',title='top years coasters introduced')
ax.set_xlabel('year introduced')
ax.set_ylabel('Count')

# %%
ax = df['Rent USD'].plot(kind='kde',title= 'coaster')

ax.set_xlabel('true')

# %%
df

# %%
df.plot(kind='scatter',x='Rent USD', y='Visa Fee USD',
    title = 'Visa Fee USD vs Rent USD')

plt.show()

# %%
sns.scatterplot(x='Rent USD', y='Visa Fee USD', data=df)

# %%
sns.pairplot(df,vars= ['Rent USD', 'Visa Fee USD'])
plt.show()

# %%
df
